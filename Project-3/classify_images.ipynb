# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# BASE_DIR = "/tf/Capstone Project/Project-3"
BASE_DIR = "/content/drive/MyDrive/Societe General/Data Science Course/Capstone Project/Project-3"

# %%
import numpy as np
import keras
import tensorflow as tf
import os
from keras.applications.vgg16 import VGG16,preprocess_input, decode_predictions
from keras.preprocessing.image import load_img,img_to_array
import numpy as np
import glob
os.chdir(BASE_DIR)
# !tree
# Out:
# .
# ├── classify_images.ipynb
# ├── Data
# │   ├── Base_Images
# │   │   ├── 1322285840_13371404fb_o.jpg
# │   │   ├── 1343073542_808b3222c1_o.jpg
# │   │   ├── 1384091526_7efb61d0f5_o.jpg
# │   │   ├── 1405312273_b857d6eff9_o.jpg
# │   │   ├── 1425035835_6a34f94a26_o.jpg
# │   │   ├── 1440186557_6833c553e0_o.jpg
# │   │   ├── 145039929_c699b8f866_o.jpg
# │   │   ├── 1473129126_fe81bc138a_o.jpg
# │   │   ├── 1477883318_a27145e085_o.jpg
# │   │   ├── 1542220015_cce653faea_o.jpg
# │   │   ├── 155096186_4fdfed77c9_o.jpg
# │   │   ├── 1556046617_f8a715e2cf_o.jpg
# │   │   ├── 1604995118_b72a35340e_o.jpg
# │   │   ├── 1631324775_9d8f5326a0_o.jpg
# │   │   ├── 1849087666_76f8bb6b7a_o.jpg
# │   │   ├── 2037444365_83ed89e427_o.jpg
# │   │   ├── 2037759663_c7eb1d127d_o.jpg
# │   │   ├── 2042946148_ed38ec8f4e_o.jpg
# │   │   ├── 2097670943_87680e3255_o.jpg
# │   │   ├── 2114088242_fbe50db702_o.jpg
# │   │   ├── 2119521895_9e2d31942b_o.jpg
# │   │   ├── 211962450_317eda6dbc_o.jpg
# ...

# %%
all_images = glob.glob("./Data/Base_Images/*.jpg") + glob.glob("./Data/Base_Images/*.png")
len(all_images)
# Out:
# 200

# %%
def preprocess(im):
    im=img_to_array(im)
    im=np.expand_dims(im,axis=0)
    im=preprocess_input(im)
    return im[0]

# %%
model = VGG16(include_top = True)
# Out:
# ...
# 553476096/553467096 [==============================] - 7s 0us/step

# %%
preprocessed_images = []
for image in all_images:
    im = load_img(image, target_size=(224,224,3))
    preprocessed_images.append(preprocess(im))

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
def get_the_top_prediction(path_to_image):
  im = load_img(path_to_image, target_size=(224, 224, 3))
  im=img_to_array(im)
  im=np.expand_dims(im,axis=0)
  im=preprocess_input(im)
  preds = model.predict(im)
  decoded_prediction = decode_predictions(preds, top = 1)[0][0][1]
  return decoded_prediction

# %%
dict_1 = {}
for image_path in all_images:
  prediction = get_the_top_prediction(image_path)
  print(prediction)
  dict_1[image_path] = prediction
# Out:
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# airliner
# airliner
# airliner
# airliner
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# acoustic_guitar
# airliner
# airliner
# airliner
# airliner
# acoustic_guitar
# acoustic_guitar
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# airliner
# Arabian_camel
# Arabian_camel
# Arabian_camel
# Arabian_camel
# airliner
# airliner
# airliner
# airliner
# Arabian_camel
# Arabian_camel
# Arabian_camel
# Arabian_camel
# airliner
# airliner
# Arabian_camel
# Arabian_camel
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# Chihuahua
# ...

# %%
list(dict_.values())[0][0][1]
# Out:
# 'acoustic_guitar'

# %%
set([i[0][1] for i in list(dict_.values())])
# Out:
# {'Arabian_camel',
#  'Chihuahua',
#  'German_shepherd',
#  'acoustic_guitar',
#  'airliner',
#  'church',
#  'laptop',
#  'tabby',
#  'violin'}

# %%
dict_
# Out:
# {'./Data/Base_Images/1322285840_13371404fb_o.jpg': [('n02690373',
#    'airliner',
#    0.96722364)],
#  './Data/Base_Images/1343073542_808b3222c1_o.jpg': [('n02437312',
#    'Arabian_camel',
#    0.9112838)],
#  './Data/Base_Images/1384091526_7efb61d0f5_o.jpg': [('n02123045',
#    'tabby',
#    0.70527846)],
#  './Data/Base_Images/1405312273_b857d6eff9_o.jpg': [('n03642806',
#    'laptop',
#    0.6659367)],
#  './Data/Base_Images/1425035835_6a34f94a26_o.jpg': [('n02085620',
#    'Chihuahua',
#    0.6810373)],
#  './Data/Base_Images/1440186557_6833c553e0_o.jpg': [('n03028079',
#    'church',
#    0.27227592)],
#  './Data/Base_Images/145039929_c699b8f866_o.jpg': [('n02106662',
#    'German_shepherd',
#    0.956188)],
#  './Data/Base_Images/1473129126_fe81bc138a_o.jpg': [('n02106662',
#    'German_shepherd',
#    0.8845179)],
#  './Data/Base_Images/1477883318_a27145e085_o.jpg': [('n02690373',
#    'airliner',
#    0.7179902)],
# ...
